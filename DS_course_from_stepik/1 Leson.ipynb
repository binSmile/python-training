# %%
import pandas as pd
import numpy as np
from jupyter_client.adapter import code_to_line

# %%
student_prefomance = pd.read_csv('StudentsPerformance.csv')

# %%
student_prefomance.groupby('gender').aggregate({'writing score':'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
student_prefomance.shape
# Out:
# (1000, 8)

# %%
student_prefomance.iloc[5:6,0:5]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 5  female        group B          associate's degree  standard
#
#   test preparation course
# 5                    none

# %%
spn = student_prefomance.iloc[[1,2,7,9,100]]

# %%
spn.index = ['Glasha','Kat', 'Bob', 'Suse','Stiv']

# %%
spn
# Out:
#         gender race/ethnicity parental level of education         lunch  \
# Glasha  female        group C                some college      standard
# Kat     female        group B             master's degree      standard
# Bob       male        group B                some college  free/reduced
# Suse    female        group B                 high school  free/reduced
# Stiv      male        group B                some college      standard
#
#        test preparation course  math score  reading score  writing score
# Glasha               completed          69             90             88
# Kat                       none          90             95             93
# Bob                       none          40             43             39
# Suse                      none          38             60             50
# Stiv                      none          79             67             67

# %%
spn.loc[['Glasha','Kat'],['lunch']]
# Out:
#            lunch
# Glasha  standard
# Kat     standard

# %%
student_prefomance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
titanicdf = pd.read_csv('https://stepik.org/media/attachments/course/4852/titanic.csv')

# %%
titanicdf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanicdf.dtypes.value_counts()
# Out:
# int64      5
# object     5
# float64    2
# dtype: int64

# %%
student_prefomance[student_prefomance.gender == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
mws = student_prefomance['writing score'].mean()
student_prefomance[student_prefomance['writing score'] > mws]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_prefomance[(student_prefomance['writing score'] > 90) & (student_prefomance.gender == 'female')]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 94   female        group B                some college      standard
# 106  female        group D             master's degree      standard
# 110  female        group D          associate's degree  free/reduced
# 114  female        group E           bachelor's degree      standard
# 122  female        group C                some college      standard
# 164  female        group E             master's degree      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 229  female        group C                some college      standard
# 268  female        group D          associate's degree      standard
# 276  female        group C            some high school      standard
# ...

# %%
(student_prefomance.lunch == 'free/reduced').mean()
# Out:
# 0.355

# %%
count = student_prefomance.shape[0]
student_prefomance[student_prefomance.lunch == 'free/reduced'].shape[0]/count
# Out:
# 0.355

# %%
student_prefomance.lunch.value_counts(normalize=True)
# Out:
# standard        0.645
# free/reduced    0.355
# Name: lunch, dtype: float64

# %%
a1 = student_prefomance[student_prefomance.lunch  == 'standard'][['math score', 'reading score','writing score']].mean()
a2 = student_prefomance[student_prefomance.lunch  != 'standard'][['math score', 'reading score','writing score']].mean()
student_prefomance.lunch.value_counts(normalize=True)
v1 = student_prefomance[student_prefomance.lunch == 'standard'][['math score', 'reading score', 'writing score']].var()
v2 = student_prefomance[student_prefomance.lunch != 'standard'][['math score', 'reading score', 'writing score']].var()

# %%
student_prefomance.groupby('lunch').mean()
student_prefomance.groupby('lunch').var().plot.bar()
# Out:
# <AxesSubplot:xlabel='lunch'>

# %%
student_prefomance.filter(like='score')
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles
# ...

# %%
dotadf.groupby('legs').describe()
# Out:
#      Unnamed: 0                                                         id  \
#           count       mean        std   min   25%   50%   75%    max count
# legs
# 0          11.0  46.000000  32.227318   9.0  20.0  38.0  76.0   92.0  11.0
# 2          95.0  58.789474  34.307091   0.0  29.5  58.0  86.5  116.0  95.0
# 4           7.0  61.714286  31.721256   2.0  53.0  61.0  84.0   95.0   7.0
# 6           3.0  68.000000  46.679760  15.0  50.5  86.0  94.5  103.0   3.0
# 8           1.0  59.000000        NaN  59.0  59.0  59.0  59.0   59.0   1.0
#
#
#            mean        std   min   25%   50%   75%    max
# legs
# 0     47.727273  32.554849  10.0  21.5  40.0  78.0   94.0
# 2     60.842105  34.994928   1.0  31.5  60.0  88.5  129.0
# 4     63.571429  32.035694   3.0  55.0  63.0  86.0   97.0
# 6     69.666667  47.247575  16.0  52.0  88.0  96.5  105.0
# 8     61.000000        NaN  61.0  61.0  61.0  61.0   61.0

# %%
lpdf = pd.read_csv('https://stepik.org/media/attachments/course/4852/accountancy.csv')

# %%
lpdf
# Out:
#     Unnamed: 0 Executor Type  Salary
# 0            0     Pupa    D      63
# 1            1     Pupa    A     158
# 2            2     Pupa    D     194
# 3            3     Pupa    E     109
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 7            7     Pupa    F     195
# 8            8     Pupa    A     115
# 9            9     Pupa    E      65
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 13          13     Pupa    A     217
# 14          14    Loopa    D     110
# 15          15     Pupa    F      62
# 16          16     Pupa    A      55
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 19          19     Pupa    A     234
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 22          22     Pupa    C      55
# 23          23     Pupa    D     144
# ...

# %%
lpdf.groupby(['Type','Executor']).aggregate({'Salary':'sum'})
# Out:
#                Salary
# Type Executor
# A    Loopa         58
#      Pupa         965
# B    Loopa        871
#      Pupa          77
# C    Loopa        926
#      Pupa         149
# D    Loopa        964
#      Pupa         586
# E    Loopa        984
#      Pupa         656
# F    Loopa        476
#      Pupa         545

# %%
lpdf[lpdf.Type == 'F'].groupby(['Executor']).aggregate({'Salary':'mean'})
# Out:
#           Salary
# Executor
# Loopa     238.00
# Pupa      136.25

# %%
lpdf.drop('Unnamed: 0',axis=1)\
    .groupby(['Type','Executor'], as_index=False)\
    .mean()\
    .sort_values(['Type','Salary'], ascending=[True,False])\
    .groupby('Type')\
    .head(1)
# Out:
#    Type Executor      Salary
# 1     A     Pupa  160.833333
# 2     B    Loopa  145.166667
# 4     C    Loopa  154.333333
# 7     D     Pupa  146.500000
# 8     E    Loopa  164.000000
# 10    F    Loopa  238.000000

# %%
(lpdf[lpdf['Executor']=='Pupa'].groupby(['Type']).mean())>(lpdf[lpdf['Executor']=='Loopa'].groupby(['Type']).mean())
# Out:
#       Unnamed: 0  Salary
# Type
# A          False    True
# B           True   False
# C          False   False
# D          False    True
# E          False   False
# F           True   False

# %%
dotadf.groupby(['attack_type','primary_attr'],as_index=False).count()
# Out:
#   attack_type primary_attr  Unnamed: 0  id  legs  localized_name  name  roles
# 0       Melee          agi          19  19    19              19    19     19
# 1       Melee          int           2   2     2               2     2      2
# 2       Melee          str          35  35    35              35    35     35
# 3      Ranged          agi          18  18    18              18    18     18
# 4      Ranged          int          40  40    40              40    40     40
# 5      Ranged          str           3   3     3               3     3      3

# %%
dotadf.drop('Unnamed: 0',axis=1)\
    .groupby(['attack_type','primary_attr'], as_index=False)\
    .count()\
    .head(1)
# Out:
#   attack_type primary_attr  id  legs  localized_name  name  roles
# 0       Melee          agi  19    19              19    19     19

# %%
dotadf[['attack_type','primary_attr']]\
    .groupby(['attack_type','primary_attr'],as_index=False)\
    .count()
# Out:
#   attack_type primary_attr
# 0       Melee          agi
# 1       Melee          int
# 2       Melee          str
# 3      Ranged          agi
# 4      Ranged          int
# 5      Ranged          str

# %%
dotadf
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
dotadf = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv',index_col=0)

# %%
dotadf['descr'] = (dotadf['attack_type'] + ' ' + dotadf['primary_attr'])

# %%
dotadf.groupby(['descr']).aggregate({'descr':'count'})\
# Out:
#             descr
# descr
# Melee agi      19
# Melee int       2
# Melee str      35
# Ranged agi     18
# Ranged int     40
# Ranged str      3

# %%
dotadf.filter(items=['attack_type','primary_attr']).mode
# Out:
# <bound method DataFrame.mode of     attack_type primary_attr
# 0         Melee          agi
# 1         Melee          str
# 2        Ranged          int
# 3         Melee          agi
# 4        Ranged          int
# ..          ...          ...
# 112       Melee          agi
# 113      Ranged          int
# 114       Melee          agi
# 115      Ranged          int
# 116       Melee          str
#
# [117 rows x 2 columns]>

# %%
dotadf.groupby(['attack_type', 'primary_attr']).agg({'id': 'count'}).sort_values('id', ascending=False)
# Out:
#                           id
# attack_type primary_attr
# Ranged      int           40
# Melee       str           35
#             agi           19
# Ranged      agi           18
#             str            3
# Melee       int            2

# %%
dotadf.groupby(['attack_type','primary_attr']).size()
# Out:
# attack_type  primary_attr
# Melee        agi             19
#              int              2
#              str             35
# Ranged       agi             18
#              int             40
#              str              3
# dtype: int64

# %%
concentrations =  pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')
concentrations
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
t = concentrations[concentrations.genus == 'Fucus']\
    .filter(['alanin','genus'])\
    .groupby('genus', as_index=False)\
    .describe()

# %%
t[[('alanin','min'),('alanin','mean'),('alanin','max')]]
# Out:
#      alanin
#         min      mean       max
# 0  0.346431  3.566411  6.641303

# %%
concentrations\
    .groupby('genus')\
    .agg(['min', 'mean', 'max'])\
    .loc['Fucus', 'alanin']\
    .round(2)
# Out:
# C:\Users\al\AppData\Local\Temp\ipykernel_4208\3265308849.py:1: FutureWarning: ['species', 'group'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   concentrations\
# min     0.35
# mean    3.57
# max     6.64
# Name: Fucus, dtype: float64

# %%
concentrations\
    .groupby('genus')\
    .aggregate({'alanin': ['min', 'mean', 'max']})\
    .loc[['Fucus']]\
    .round(2)
# Out:
#       alanin
#          min  mean   max
# genus
# Fucus   0.35  3.57  6.64

# %%
'{min} {mean} {max}'.format(
    **concentrations.loc[concentrations.genus == 'Fucus', 'alanin'] \
        .agg(['min', 'mean', 'max']) \
        .round(2)
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [86], line 1
# ----> 1 str(
#       2     **concentrations.loc[concentrations.genus == 'Fucus', 'alanin'] \
#       3         .agg(['min', 'mean', 'max']) \
#       4         .round(2)
#       5 )
#
# TypeError: 'min' is an invalid keyword argument for str()

# %%
concentrations.loc[concentrations.genus == 'Fucus', 'alanin'] \
        .agg(['min', 'mean', 'max']) \
        .round(2)
# Out:
# min     0.35
# mean    3.57
# max     6.64
# Name: alanin, dtype: float64

# %%
concentrations[['group','citrate']]\
    .groupby('group')\
    .agg('std')\
    .apply(np.square)
# Out:
#         citrate
# group
# brown  5.468942
# green  3.950113
# red         NaN

# %%
concentrations.groupby(['group'])\
    .count()
# Out:
#        species  genus  sucrose  alanin  citrate  glucose  oleic_acid
# group
# brown        6      6        6       6        6        6           6
# green        3      3        3       3        3        3           3
# red          1      1        1       1        1        1           1

# %%
df = concentrations\
    .groupby('group')['sucrose']\
    .agg(['min','max'])
df['ampl'] = df['max'] - df['min']
df['ampl'].round(2)
# Out:
# group
# brown    5.19
# green    3.26
# red      0.00
# Name: ampl, dtype: float64

# %%
concentrations.groupby('group') \
    .agg({'citrate': 'var', 'sucrose': lambda x: x.max() - x.min(), 'glucose': 'count'}) \
    .round(2)
# Out:
#        citrate  sucrose  glucose
# group
# brown     5.47     5.19        6
# green     3.95     3.26        3
# red        NaN     0.00        1

# %%
concentrations.groupby('group').aggregate({"species":'nunique', 'citrate':'var','sucrose': np.ptp})
# Out:
#        species   citrate   sucrose
# group
# brown        6  5.468942  5.189345
# green        3  3.950113  3.259662
# red          1       NaN  0.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sbs

# %%
student_prefomance.plot.scatter(x='math score',y='reading score')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='reading score'>

# %%
sbs.lmplot(student_prefomance,x='math score',y='reading score',hue='gender')

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df['income']
# Out:
# 2018-11-30     20
# 2018-12-31     60
# 2019-01-31    180
# 2019-02-28    380
# 2019-03-31    660
# Name: income, dtype: int64

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
df.income.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv('dataset_209770_6.txt',sep=' ')

# %%
df.plot.scatter(x='x',y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv',index_col=0)

# %%
df
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
sbs.heatmap(df, cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv', index_col=0)

# %%
df
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles
# ...

# %%
df['nroles'] = df.roles.str.count(',')+1

# %%
df.nroles.hist()
df.nroles.median()
# Out:
# 4.0

# %%
irisdf = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv',index_col=0)

# %%
irisdf.columns
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width',
#        'species'],
#       dtype='object')

# %%
irisdf.columns
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width',
#        'species'],
#       dtype='object')

# %%
plt.figure("Test Plots")
for column in irisdf:
    sbs.kdeplot(irisdf[column],label=column)
plt.legend()
plt.show()

# %%
sns.kdeplot(data=irisdf)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sbs.violinplot(irisdf)
# Out:
# <AxesSubplot:>

# %%
ic = irisdf.drop('species',axis=1).corr()
sns.heatmap(ic,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(irisdf,hue="species", height=2)

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')
my_stat
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 4     0  10.0  B -1.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [500 rows x 4 columns]

# %%
#subset_1 сохраните только первые 10 строк и только 1 и 3 колонку.
subset_1 = my_stat.iloc[:10,[0,2]]
#  В переменную с именем subset_2 сохраните все строки кроме 1 и 5 и только 2 и 4 колонку.
subset_2 = my_stat.drop(index=[0,4])\
    .drop(columns=['V1','V3'])

# %%
# subset_1 сохраните только те наблюдения, у которых значения переменной V1  строго больше 0, и значение переменной V3  равняется 'A'.
subset_1 = my_stat[(my_stat['V1'] > 0) & (my_stat['V3'] == 'A') ]
# subset_2  сохраните только те наблюдения, у которых значения переменной V2  не равняются 10, или значения переменной V4 больше или равно 1.
subset_2 = my_stat[(my_stat['V2'] != 10) | (my_stat['V4'] >= 1)]

# %%
my_stat['V5'] = my_stat['V1'] + my_stat['V4']
my_stat['V6'] = np.log(my_stat['V2'])

# %%
 my_stat = my_stat.rename(columns=
    {'V1':'session_value',
     'V2':'group',
     'V3':'time',
     'V4':'n_users'},
)

# %%
my_stat.session_value.fillna(value=0,inplace=True)
# Out:
#      session_value  group time  n_users   V5        V6
# 0                2   13.0    B      1.0  3.0  2.564949
# 1               -1    7.0    B      1.0  0.0  1.945910
# 2                0   11.0    A      0.0  0.0  2.397895
# 3                2   11.0    A      2.0  4.0  2.397895
# 4                0   10.0    B     -1.0 -1.0  2.302585
# ..             ...    ...  ...      ...  ...       ...
# 495              1    8.0    A     -1.0  0.0  2.079442
# 496              3    8.0    A      1.0  4.0  2.079442
# 497             -1   11.0    B      2.0  1.0  2.397895
# 498              1   11.0    A      2.0  3.0  2.397895
# 499              0    8.0    B      1.0  1.0  2.079442
#
# [500 rows x 6 columns]

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_1.csv')
mmm = my_stat.n_users[my_stat.n_users>=0].median()
my_stat.loc[my_stat['n_users'] < 0, 'n_users'] = mmm

# %%
my_stat.groupby(['group'],as_index=False)\
    .agg({'session_value':'mean'})\
    .rename(columns={'group':'group',
                     'session_value':'mean_session_value'})
# Out:
#       group  mean_session_value
# 0  5.571429            5.571429
# 1         A            1.333333
# 2         B            1.333333

# %%
mean_session_value_data
# Out:
#                    mean_session_value
# group
# 5.571428571428571            5.571429
# A                            1.333333
# B                            1.333333

# %%
my_stat.loc[my_stat['n_users'] < 0, 'n_users']
# Out:
# Series([], Name: n_users, dtype: float64)
